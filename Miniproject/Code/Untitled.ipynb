# %%
import pandas as pd
import scipy as sc
import matplotlib.pylab as pl
import seaborn as sns 
data=pd.read_csv("../Data/CRat.csv")

# %%
data.head()
# Out:
#       ID DataType           ORIGINAL_TraitID  \
# 0  39835      new  Resource Consumption Rate
# 1  39835      new  Resource Consumption Rate
# 2  39835      new  Resource Consumption Rate
# 3  39835      new  Resource Consumption Rate
# 4  39835      new  Resource Consumption Rate
#
#                             ORIGINAL_TraitDefinition  TraitValue  \
# 0  The number of resource consumed per number of ...     8.67993
# 1  The number of resource consumed per number of ...     7.66727
# 2  The number of resource consumed per number of ...     8.67993
# 3  The number of resource consumed per number of ...    18.44480
# 4  The number of resource consumed per number of ...    17.35990
#
#                           TraitUnit  N_TraitValue  \
# 0  Individual/(Individual*120 mins)      0.001206
# 1  Individual/(Individual*120 mins)      0.001065
# 2  Individual/(Individual*120 mins)      0.001206
# 3  Individual/(Individual*120 mins)      0.002562
# 4  Individual/(Individual*120 mins)      0.002411
#
#                            ConTaxa             ResTaxa  \
# 0  Cyclops bicuspidatus Claus 1857  Panagrolaimus spp.
# 1  Cyclops bicuspidatus Claus 1857  Panagrolaimus spp.
# 2  Cyclops bicuspidatus Claus 1857  Panagrolaimus spp.
# 3  Cyclops bicuspidatus Claus 1857  Panagrolaimus spp.
# 4  Cyclops bicuspidatus Claus 1857  Panagrolaimus spp.
#
#                               ConTaxaStage  ... ConSizType CON_ORIGINAL_value  \
# 0  Cyclops bicuspidatus Claus 1857 [adult]  ...   dry mass          6.23E-009
# 1  Cyclops bicuspidatus Claus 1857 [adult]  ...   dry mass          6.23E-009
# 2  Cyclops bicuspidatus Claus 1857 [adult]  ...   dry mass          6.23E-009
# 3  Cyclops bicuspidatus Claus 1857 [adult]  ...   dry mass          6.23E-009
# 4  Cyclops bicuspidatus Claus 1857 [adult]  ...   dry mass          6.23E-009
#
#   CON_ORIGINAL_unit Con_Siz_reference ResSizType  RES_ORIGINAL_value  \
# 0          kilogram          original   dry mass        6.000000e-11
# 1          kilogram          original   dry mass        6.000000e-11
# 2          kilogram          original   dry mass        6.000000e-11
# 3          kilogram          original   dry mass        6.000000e-11
# 4          kilogram          original   dry mass        6.000000e-11
#
#    RES_ORIGINAL_unit Res_Siz_reference  \
# 0           kilogram          original
# 1           kilogram          original
# 2           kilogram          original
# 3           kilogram          original
# 4           kilogram          original
#
#                                             Citation FigureTable
# 0  [91] Muschiol D. et al. Predator-prey relation...       Fig 1
# 1  [91] Muschiol D. et al. Predator-prey relation...       Fig 1
# 2  [91] Muschiol D. et al. Predator-prey relation...       Fig 1
# 3  [91] Muschiol D. et al. Predator-prey relation...       Fig 1
# 4  [91] Muschiol D. et al. Predator-prey relation...       Fig 1
#
# [5 rows x 68 columns]

# %%
data_subset = data[data['ID']==2]
data_subset
# Out:
#       ID DataType           ORIGINAL_TraitID ORIGINAL_TraitDefinition  \
# 4109   2      old  Resource Consumption Rate                      NaN
# 4110   2      old  Resource Consumption Rate                      NaN
# 4111   2      old  Resource Consumption Rate                      NaN
# 4112   2      old  Resource Consumption Rate                      NaN
#
#       TraitValue                              TraitUnit  N_TraitValue  \
# 4109      1.7042  individual / (1 individual * 24 hour)      0.000020
# 4110     10.3456  individual / (1 individual * 24 hour)      0.000120
# 4111     19.0352  individual / (1 individual * 24 hour)      0.000220
# 4112     21.2201  individual / (1 individual * 24 hour)      0.000246
#
#                               ConTaxa                       ResTaxa  \
# 4109  Chaoborus trivittatus Loew 1862  Diaptomus tyrelli Poppe ????
# 4110  Chaoborus trivittatus Loew 1862  Diaptomus tyrelli Poppe ????
# 4111  Chaoborus trivittatus Loew 1862  Diaptomus tyrelli Poppe ????
# 4112  Chaoborus trivittatus Loew 1862  Diaptomus tyrelli Poppe ????
#
#                                            ConTaxaStage  ... ConSizType  \
# 4109  Chaoborus trivittatus Loew 1862 [instar 4 - 2n...  ...        NaN
# 4110  Chaoborus trivittatus Loew 1862 [instar 4 - 2n...  ...        NaN
# 4111  Chaoborus trivittatus Loew 1862 [instar 4 - 2n...  ...        NaN
# 4112  Chaoborus trivittatus Loew 1862 [instar 4 - 2n...  ...        NaN
#
#      CON_ORIGINAL_value CON_ORIGINAL_unit Con_Siz_reference ResSizType  \
# 4109                NaN               NaN               NaN        NaN
# 4110                NaN               NaN               NaN        NaN
# 4111                NaN               NaN               NaN        NaN
# 4112                NaN               NaN               NaN        NaN
#
#       RES_ORIGINAL_value  RES_ORIGINAL_unit Res_Siz_reference  \
# 4109                 NaN                NaN               NaN
# 4110                 NaN                NaN               NaN
# 4111                 NaN                NaN               NaN
# 4112                 NaN                NaN               NaN
#
#                                                Citation FigureTable
# 4109  Fedorenko A.Y. 1975. Feeding characteristic an...    Figure 2
# 4110  Fedorenko A.Y. 1975. Feeding characteristic an...    Figure 2
# 4111  Fedorenko A.Y. 1975. Feeding characteristic an...    Figure 2
# 4112  Fedorenko A.Y. 1975. Feeding characteristic an...    Figure 2
#
# [4 rows x 68 columns]

# %%
sns.lmplot("ConTemp", "OriginalTraitValue", data=data_subset, fit_reg=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-fcdce691f900> in <module>
# ----> 1 sns.lmplot("ConTemp", "OriginalTraitValue", data=data_subset, fit_reg=False)
#
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     549     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     550     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 551     data = data[cols]
#     552
#     553     # Initialize the grid
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1183             if not (self.name == "loc" and not raise_missing):
#    1184                 not_found = list(set(key) - set(ax))
# -> 1185                 raise KeyError("{} not in index".format(not_found))
#    1186
#    1187             # we skip the warning on Categorical/Interval
#
# KeyError: "['OriginalTraitValue'] not in index"
